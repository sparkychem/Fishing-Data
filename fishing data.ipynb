# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns

# %%
df = pd.read_csv('full_dataset.csv')
df.head()
# Out:
#     y_          ID  engine_age  length   power  month    landing  weight  \
# 0  1.0  1993001257        10.0   10.50   367.0     44      RISØR     5.0
# 1  1.0  1993005128        26.0   21.30   970.0    131  BÅTSFJORD    19.0
# 2  0.0  1996007882        32.0   12.13   190.0    170     ØKSNES     0.0
# 3  0.0  1999009281         8.0   27.45  1014.0     89     AVERØY     0.0
# 4  1.0  1986007228        31.0    9.22    80.0    216    BRØNNØY    12.5
#
#     value  value_cpi  ...  year  patch   dist patch_area  weight_lym  \
# 0   95.70     119.62  ...   3.0  09-16   13.6       3229    0.000000
# 1  564.59     611.69  ...  10.0  03-03   59.6       2122    0.000000
# 2    0.00       0.00  ...  14.0  04-27  286.7       4596    0.000000
# 3    0.00       0.00  ...   7.0  42-72  461.5       3038    0.000000
# 4  816.34     769.41  ...  18.0  06-23   40.2       2555    0.820069
#
#    weight_lm    val_lm  val_lym  nao_index  surf_temp
# 0   1.000000  1.000000      0.0     -0.070     286.90
# 1   0.371367  0.359628      0.0     -1.616     276.25
# 2   0.000000  0.000000      0.0      1.335     279.03
# 3   0.000000  0.000000      0.0      0.664     282.22
# 4   0.000000  0.000000      0.0      0.882     284.25
#
# [5 rows x 22 columns]

# %%
df_new = df.dropna()
df_new.head()
# Out:
#     y_          ID  engine_age  length   power  month    landing  weight  \
# 0  1.0  1993001257        10.0   10.50   367.0     44      RISØR     5.0
# 1  1.0  1993005128        26.0   21.30   970.0    131  BÅTSFJORD    19.0
# 2  0.0  1996007882        32.0   12.13   190.0    170     ØKSNES     0.0
# 3  0.0  1999009281         8.0   27.45  1014.0     89     AVERØY     0.0
# 4  1.0  1986007228        31.0    9.22    80.0    216    BRØNNØY    12.5
#
#     value  value_cpi  ...  year  patch   dist patch_area  weight_lym  \
# 0   95.70     119.62  ...   3.0  09-16   13.6       3229    0.000000
# 1  564.59     611.69  ...  10.0  03-03   59.6       2122    0.000000
# 2    0.00       0.00  ...  14.0  04-27  286.7       4596    0.000000
# 3    0.00       0.00  ...   7.0  42-72  461.5       3038    0.000000
# 4  816.34     769.41  ...  18.0  06-23   40.2       2555    0.820069
#
#    weight_lm    val_lm  val_lym  nao_index  surf_temp
# 0   1.000000  1.000000      0.0     -0.070     286.90
# 1   0.371367  0.359628      0.0     -1.616     276.25
# 2   0.000000  0.000000      0.0      1.335     279.03
# 3   0.000000  0.000000      0.0      0.664     282.22
# 4   0.000000  0.000000      0.0      0.882     284.25
#
# [5 rows x 22 columns]

# %%
y = df_new['weight'].values
x = df_new['length'].values

# %%
x = x.reshape(-1,1)

# %%
model = LinearRegression().fit(x, y)

# %%
predictions = model.predict(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,train_size=0.04,test_size=.03,random_state=1)
lm = LinearRegression()
lm.fit(x_train, y_train)
y_predict = lm.predict(x_test)
r2_score(y_test, y_predict)
# Out:
# 0.08543853746706676

# %%
plt.figure(figsize=(15, 8))
plt.scatter(x_test, y_test, color='blue')


plt.xlabel('Panjang Kapal')
plt.ylabel('Berat ikan')
plt.title('Testing Data')
plt.show()
